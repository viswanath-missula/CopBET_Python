# %%
# Import dependencies
import CopBET_final as CopBET
import pandas as pd
import numpy as np
import os
from scipy.io import loadmat

# %% [markdown]
# Load all the necessary dependencies. Note that `scipy.io` is only used to load the .mat files in this case specifically.

# %%
# Create helper function
def load_mat_roi_data(base_path, atlas_name):
    roi_folder = os.path.join(base_path, "ROIdata", atlas_name)
    data_list = []
    
    # List all .mat files in the atlas directory
    if not os.path.exists(roi_folder):
        raise FileNotFoundError(f"Folder not found: {roi_folder}")
        
    mat_files = [f for f in os.listdir(roi_folder) if f.endswith('.mat')]
    
    for filename in mat_files:
        # Load the .mat file
        file_path = os.path.join(roi_folder, filename)
        mat_contents = loadmat(file_path)
        
        # In your MATLAB code, the variable is named 'V_roi'
        if 'V_roi' in mat_contents:
            timeseries = mat_contents['V_roi'] # This is your T x N matrix
            
            # Parse metadata from filename (e.g., sub-01_ses-LSD_task-rest_run-01_bold.mat)
            parts = filename.split('_')
            data_list.append({
                "data": timeseries.tolist(), # Convert to list for JSON compatibility
                "subject": parts[0],
                "condition": parts[1],
                "session": parts[3], # run-01, run-03, etc.
                "filename": filename
            })
    
    data_list = data_list[:3][::-1] + [data_list[-1]]  # Reorder to match MATLAB code
    return pd.DataFrame(data_list)

# %% [markdown]
# This helper function is specifically to load all the .mat files from the LSD dataset and assemble them into a pandas dataframe of size nx1 (with n=4). This function is specific to the CopBET folder's file hierarchy so it might not work for other datasets, although you can use the logic to assemble the same dataframe for the computation.

# %%
# Define initial variables
data_path = r"/usr/local/CopBET/LSDdata/exampledata"    # Path to data
ext = "bold_shortened"    # Extension of data
task = "rest"    # Task name ("music" or "rest")
session_types = ["LSD", "PLCB"]

# %% [markdown]
# Here the path to the LSD data is defined, along with the file path extension, task, and session types. These variables are used to compose `criteria` that `CopBET.return_target_files()` uses to filter out target subjects.

# %%
# Path to CopBET installation and name of directory to save results
CopBET_path = "/usr/local/CopBET"
dir_name = f"CopBET_LSD_data_ses-{'_'.join(session_types)}_task-{task}"    # Name of directory to save results

# %% [markdown]
# Define the path to your CopBET installation (very important!) and the directory where you would like the entropy results to be saved.
#
# This wrapper works by parsing the Python arguments into the MATLAB engine and running the original CopBET functions and then parsing the results back. **This means that you need the original CopBET folder downloaded _and_ a valid MATLAB license.**
#
# You can download the CopBET git repository using the following command.
#
# `git clone https://github.com/anders-s-olsen/CopBET.git`

# %%
# Define criteria and parameters
criteria = [ext, task, session_types]    # Criteria to select target files (from file name)
params = {
    "LEiDA_k" : 3,
    "TR" : 2.2,
    "LZ_types" : ['LZ78temporal', 'LZ78spatial', 'LZ76temporal', 'LZ76spatial'],
    "NGSC_workers" : 32,
    "Atlas_path" : "/usr/local/CopBET/Atlases/Schaefer1000_2mm.nii"
}

# Extract the atlas into a numpy-operable format for later entropy functions.
numpy_atlas = CopBET.load_atlas(params["Atlas_path"])
numpy_atlas_4D, atlas_4D_labels = CopBET.convert_atlas_to_4D(numpy_atlas)

# %% [markdown]
# Here the criteria that is used to select target files is defined. Note that any sublists included in `criteria` (like `session_types`) result in `return_target_files()` looking for any one of the elements of the sublist in the file names. More importantly, the parameters for the CopBET computations are setup in the params dictionary. You can change these values here for convenience. The atlas is also extracted from its path.

# %%
# Get target files
subjects = [f"{data_path}/{f}/ses-{st}/func" for st in session_types for f in os.listdir(data_path) if f != "ROIdata"]    # All possible subjects
targets = CopBET.return_target_files(subjects, criteria)    # Filtered target files based on criteria

# Reorder targets to match ordering used in MATLAB code. DELETE/IGNORE if using own data.
targets = targets[2:] + targets[:2]

print("Defined initial variables")
# Out:
# Defined initial variables

# %% [markdown]
# The subjects list finds and includes all the files in the LSDdata directory except those in the ROIdata folder. You can adjust this line based on the naming conventions of your files. `targets` uses the aforementioned `return_target_files()`  to filter all the subjects based on the provided criteria.

# %%
# Create timeseries and filenames tables
roi_data_path = "/usr/local/CopBET/LSDdata/exampledata"
ts_atlas_name = "Schaefer1000"

CopBET.make_directory(dir_name)
tbl_filenames = pd.DataFrame(targets, columns=["targets"])
tbl_timeseries = load_mat_roi_data(base_path=roi_data_path, atlas_name=ts_atlas_name)

# %% [markdown]
# Creates the directory to save the entropy results. Creates a table with file paths for some specific entropy functions. Uses the helper function to load the LSD example data into a dataframe as described above.

# %%
ts_atlas_path = "/usr/local/CopBET/Atlases/Schaefer1000_2mm.nii"
timeseries_save_path = f"{dir_name}/CopBET_LSD_data_ses-{'_'.join(session_types)}_task-{task}_ts.pkl"
# tbl_timeseries = CopBET.get_timeseries(targets, ts_atlas_path, timeseries_save_path).drop(columns="target")

print("Created tables")
# Out:
# Created tables

# %% [markdown]
# Do not run this code snippet if using the .mat ROI data. You can use this if you need to compute your timeseries from .nii files to create `tbl_timeseries`. `get_timeseries()` saves the table of computed timeseries as a .pkl so that the timeseries need not be recomputed every time you run the code or change any parameters.

# %%
# Assemble computer by defining parameters
computer = CopBET.CopBET_computer(
    matlab_path = CopBET_path,
    df_timeseries = tbl_timeseries,
    df_filenames = tbl_filenames,
    results_path = dir_name,
    overwrite = True,    # optional, default is False
    keepdata = False,    # optional, default is True
    parallel = True,    # optional, default is True
    NRU_specific = False    # optional, default is False
)

print("Assembled computer")
# Out:
# Assembled computer

# %% [markdown]
# Here, we finally assemble our computer for the entropy calculations. Note that all the prior code was the assemble the needed variables for this code snippet. `overwrite` determines whether existing .csv files with entropy results should be overwritten when entropy is recomputed. `keepdata` determines whether the data input to the function should be saved and output with the results. I recommend against setting it to `True` unless you specifically want the timeseries of each target saved along with each entropy result. `parallel` determines whether parallel workers are implemented for complex computations (recommended, especially for DCC). `NRU_specific` is intended to allow the original developers to bypass user input and make use of their pre-defined directories (you would probably never set this to `True`).

# %%
# Compute entropies
computer.von_Neumann_entropy(savedata=True)
print("von_Neumann_entropy finished")

computer.metastate_series_complexity(savedata=True)
print("metastate_series_complexity finished")

computer.geodesic_entropy(savedata=True)
print("geodesic_entropy finished")

computer.LEiDA_transition_entropy(K=params["LEiDA_k"], savedata=True)
print("LEiDA_transition_entropy finished")

computer.temporal_entropy(TR=params["TR"], savedata=True)
print("temporal_entropy finished")

for lz_type in params["LZ_types"]:
    computer.time_series_complexity(LZtype=lz_type, savedata=True)
    print(f"time_series_complexity ({lz_type}) finished")

computer.NGSC(atlas_path=params["Atlas_path"], num_workers=params["NGSC_workers"], savedata=True)
print("NGSC finished")

computer.degree_distribution_entropy(savedata=True)
print("degree_distribution_entropy finished")

computer.intranetwork_synchrony(atlas=numpy_atlas_4D, savedata=True)
print("intranetwork_synchrony finished")

computer.sample_entropy(atlas=numpy_atlas, compute=True, savedata=True)
print("sample_entropy finished")

computer.diversity_coefficient(savedata=True)
print("diversity_coefficient finished")

computer.DCC_entropy(compute=True, savedata=True)
print("DCC_entropy finished")
# Out:
# Saved DataFrame to CopBET_LSD_data_ses-LSD_PLCB_task-rest/von_Neumann_entropy_CopBET_LSD_data_ses-LSD_PLCB_task-rest.csv
# von_Neumann_entropy finished
# Concatenating data
# running kmeans and LZ calculations
# Starting parallel pool (parpool) using the 'Processes' profile ...
# Connected to parallel pool with 32 workers.
# Replicate 8, 18 iterations, total sum of distances = 520.219.
# Replicate 23, 15 iterations, total sum of distances = 521.23.
# Replicate 10, 11 iterations, total sum of distances = 520.616.
# Replicate 4, 12 iterations, total sum of distances = 520.127.
# Replicate 30, 9 iterations, total sum of distances = 519.749.
# Replicate 9, 11 iterations, total sum of distances = 517.844.
# Replicate 12, 11 iterations, total sum of distances = 518.375.
# Replicate 6, 12 iterations, total sum of distances = 519.46.
# Replicate 24, 12 iterations, total sum of distances = 520.45.
# Replicate 14, 19 iterations, total sum of distances = 515.33.
# Replicate 27, 20 iterations, total sum of distances = 515.857.
# Replicate 5, 25 iterations, total sum of distances = 518.436.
# Replicate 2, 12 iterations, total sum of distances = 519.926.
# Replicate 21, 15 iterations, total sum of distances = 517.774.
# Replicate 17, 12 iterations, total sum of distances = 520.957.
# Replicate 31, 13 iterations, total sum of distances = 516.417.
# Replicate 13, 10 iterations, total sum of distances = 519.044.
# Replicate 47, 11 iterations, total sum of distances = 517.745.
# Replicate 7, 22 iterations, total sum of distances = 516.54.
# Replicate 25, 17 iterations, total sum of distances = 518.127.
# Replicate 46, 14 iterations, total sum of distances = 519.447.
# Replicate 122, 18 iterations, total sum of distances = 516.33.
# Replicate 56, 17 iterations, total sum of distances = 516.315.
# Replicate 59, 11 iterations, total sum of distances = 517.756.
# Replicate 19, 19 iterations, total sum of distances = 516.956.
# Replicate 22, 27 iterations, total sum of distances = 518.368.
# Replicate 113, 13 iterations, total sum of distances = 518.18.
# Replicate 101, 26 iterations, total sum of distances = 519.104.
# Replicate 16, 28 iterations, total sum of distances = 517.289.
# Replicate 29, 7 iterations, total sum of distances = 518.909.
# Replicate 32, 16 iterations, total sum of distances = 516.043.
# Replicate 15, 28 iterations, total sum of distances = 518.614.
# Replicate 3, 26 iterations, total sum of distances = 518.887.
# Replicate 44, 13 iterations, total sum of distances = 516.152.
# Replicate 65, 13 iterations, total sum of distances = 515.973.
# Replicate 50, 13 iterations, total sum of distances = 517.715.
# Replicate 104, 12 iterations, total sum of distances = 519.926.
# Replicate 62, 35 iterations, total sum of distances = 516.394.
# Replicate 74, 14 iterations, total sum of distances = 523.311.
# Replicate 45, 25 iterations, total sum of distances = 521.016.
# Replicate 100, 16 iterations, total sum of distances = 519.593.
# Replicate 58, 19 iterations, total sum of distances = 515.809.
# Replicate 18, 42 iterations, total sum of distances = 515.967.
# Replicate 20, 31 iterations, total sum of distances = 516.452.
# Replicate 53, 21 iterations, total sum of distances = 517.639.
# Replicate 43, 16 iterations, total sum of distances = 518.365.
# Replicate 83, 17 iterations, total sum of distances = 519.286.
# Replicate 26, 39 iterations, total sum of distances = 515.55.
# Replicate 73, 17 iterations, total sum of distances = 517.349.
# Replicate 95, 17 iterations, total sum of distances = 521.062.
# Replicate 49, 12 iterations, total sum of distances = 517.661.
# Replicate 89, 14 iterations, total sum of distances = 515.992.
# Replicate 61, 16 iterations, total sum of distances = 518.687.
# Replicate 121, 34 iterations, total sum of distances = 517.651.
# Replicate 1, 17 iterations, total sum of distances = 517.728.
# Replicate 52, 15 iterations, total sum of distances = 519.424.
# Replicate 41, 25 iterations, total sum of distances = 515.785.
# Replicate 77, 11 iterations, total sum of distances = 520.518.
# Replicate 72, 18 iterations, total sum of distances = 517.134.
# Replicate 130, 24 iterations, total sum of distances = 518.403.
# Replicate 112, 41 iterations, total sum of distances = 515.735.
# Replicate 55, 41 iterations, total sum of distances = 516.552.
# Replicate 99, 24 iterations, total sum of distances = 519.332.
# Replicate 57, 28 iterations, total sum of distances = 515.958.
# Replicate 64, 20 iterations, total sum of distances = 516.023.
# Replicate 119, 11 iterations, total sum of distances = 522.071.
# Replicate 86, 14 iterations, total sum of distances = 518.056.
# Replicate 103, 22 iterations, total sum of distances = 517.316.
# Replicate 125, 18 iterations, total sum of distances = 518.691.
# Replicate 107, 29 iterations, total sum of distances = 515.823.
# Replicate 76, 9 iterations, total sum of distances = 519.74.
# Replicate 98, 15 iterations, total sum of distances = 521.614.
# Replicate 120, 12 iterations, total sum of distances = 520.438.
# Replicate 42, 25 iterations, total sum of distances = 519.759.
# Replicate 80, 24 iterations, total sum of distances = 516.234.
# Replicate 71, 31 iterations, total sum of distances = 518.78.
# Replicate 28, 15 iterations, total sum of distances = 519.653.
# Replicate 128, 22 iterations, total sum of distances = 520.988.
# Replicate 111, 10 iterations, total sum of distances = 519.409.
# Replicate 51, 26 iterations, total sum of distances = 520.604.
# Replicate 118, 9 iterations, total sum of distances = 523.706.
# Replicate 92, 16 iterations, total sum of distances = 521.776.
# Replicate 110, 11 iterations, total sum of distances = 518.529.
# Replicate 88, 10 iterations, total sum of distances = 518.099.
# Replicate 124, 10 iterations, total sum of distances = 519.194.
# Replicate 60, 30 iterations, total sum of distances = 523.312.
# Replicate 75, 13 iterations, total sum of distances = 518.465.
# Replicate 142, 17 iterations, total sum of distances = 518.307.
# Replicate 132, 27 iterations, total sum of distances = 516.307.
# Replicate 135, 17 iterations, total sum of distances = 520.614.
# Replicate 63, 14 iterations, total sum of distances = 518.865.
# Replicate 48, 20 iterations, total sum of distances = 516.043.
# Replicate 102, 17 iterations, total sum of distances = 522.199.
# Replicate 70, 13 iterations, total sum of distances = 518.007.
# Replicate 136, 16 iterations, total sum of distances = 521.212.
# Replicate 38, 23 iterations, total sum of distances = 518.285.
# Replicate 155, 19 iterations, total sum of distances = 517.399.
# Replicate 134, 7 iterations, total sum of distances = 519.223.
# Replicate 11, 34 iterations, total sum of distances = 516.876.
# Replicate 85, 18 iterations, total sum of distances = 521.795.
# Replicate 127, 12 iterations, total sum of distances = 521.868.
# Replicate 97, 12 iterations, total sum of distances = 519.824.
# Replicate 54, 22 iterations, total sum of distances = 516.621.
# Replicate 146, 15 iterations, total sum of distances = 519.705.
# Replicate 94, 33 iterations, total sum of distances = 519.931.
# Replicate 82, 38 iterations, total sum of distances = 519.049.
# Replicate 123, 15 iterations, total sum of distances = 520.492.
# Replicate 106, 28 iterations, total sum of distances = 519.82.
# Replicate 129, 29 iterations, total sum of distances = 516.877.
# Replicate 169, 8 iterations, total sum of distances = 520.353.
# Replicate 79, 24 iterations, total sum of distances = 521.866.
# Replicate 117, 9 iterations, total sum of distances = 520.924.
# Replicate 137, 11 iterations, total sum of distances = 516.669.
# Replicate 109, 14 iterations, total sum of distances = 519.555.
# Replicate 131, 22 iterations, total sum of distances = 517.772.
# Replicate 151, 17 iterations, total sum of distances = 523.218.
# Replicate 159, 12 iterations, total sum of distances = 519.161.
# Replicate 35, 30 iterations, total sum of distances = 521.754.
# Replicate 165, 21 iterations, total sum of distances = 518.543.
# Replicate 164, 19 iterations, total sum of distances = 522.889.
# Replicate 138, 17 iterations, total sum of distances = 515.783.
# Replicate 105, 12 iterations, total sum of distances = 520.902.
# Replicate 116, 15 iterations, total sum of distances = 515.431.
# Replicate 78, 14 iterations, total sum of distances = 521.846.
# Replicate 40, 25 iterations, total sum of distances = 516.682.
# Replicate 81, 21 iterations, total sum of distances = 516.015.
# Replicate 84, 19 iterations, total sum of distances = 515.864.
# Replicate 139, 22 iterations, total sum of distances = 516.988.
# Replicate 69, 20 iterations, total sum of distances = 515.992.
# Replicate 126, 22 iterations, total sum of distances = 517.717.
# Replicate 163, 19 iterations, total sum of distances = 520.281.
# Replicate 133, 26 iterations, total sum of distances = 516.953.
# Replicate 181, 12 iterations, total sum of distances = 519.412.
# Replicate 162, 38 iterations, total sum of distances = 516.04.
# Replicate 175, 13 iterations, total sum of distances = 516.666.
# Replicate 93, 18 iterations, total sum of distances = 516.993.
# Replicate 172, 20 iterations, total sum of distances = 518.521.
# Replicate 108, 18 iterations, total sum of distances = 519.276.
# Replicate 87, 21 iterations, total sum of distances = 516.01.
# Replicate 115, 11 iterations, total sum of distances = 519.152.
# Replicate 170, 15 iterations, total sum of distances = 519.544.
# Replicate 180, 12 iterations, total sum of distances = 518.518.
# Replicate 37, 17 iterations, total sum of distances = 517.042.
# Replicate 160, 43 iterations, total sum of distances = 515.347.
# Replicate 179, 18 iterations, total sum of distances = 518.201.
# Replicate 96, 17 iterations, total sum of distances = 520.596.
# Replicate 167, 44 iterations, total sum of distances = 516.024.
# Replicate 34, 19 iterations, total sum of distances = 520.887.
# Replicate 192, 11 iterations, total sum of distances = 518.567.
# Replicate 171, 22 iterations, total sum of distances = 516.275.
# Replicate 91, 31 iterations, total sum of distances = 515.886.
# Replicate 144, 27 iterations, total sum of distances = 519.786.
# Replicate 168, 25 iterations, total sum of distances = 520.942.
# Replicate 183, 10 iterations, total sum of distances = 518.966.
# Replicate 190, 14 iterations, total sum of distances = 517.725.
# Replicate 177, 21 iterations, total sum of distances = 516.852.
# Replicate 150, 15 iterations, total sum of distances = 521.061.
# Replicate 153, 17 iterations, total sum of distances = 517.562.
# Replicate 158, 12 iterations, total sum of distances = 519.353.
# Replicate 173, 19 iterations, total sum of distances = 516.22.
# Replicate 147, 16 iterations, total sum of distances = 520.334.
# Replicate 154, 13 iterations, total sum of distances = 519.433.
# Replicate 189, 13 iterations, total sum of distances = 528.781.
# Replicate 68, 21 iterations, total sum of distances = 522.367.
# Replicate 182, 37 iterations, total sum of distances = 515.993.
# Replicate 33, 17 iterations, total sum of distances = 522.254.
# Replicate 193, 21 iterations, total sum of distances = 516.581.
# Replicate 39, 13 iterations, total sum of distances = 519.938.
# Replicate 187, 13 iterations, total sum of distances = 517.731.
# Replicate 114, 17 iterations, total sum of distances = 519.908.
# Replicate 185, 21 iterations, total sum of distances = 519.965.
# Replicate 178, 24 iterations, total sum of distances = 516.955.
# Replicate 176, 14 iterations, total sum of distances = 517.783.
# Replicate 161, 14 iterations, total sum of distances = 519.973.
# Replicate 198, 10 iterations, total sum of distances = 517.826.
# Replicate 145, 19 iterations, total sum of distances = 517.536.
# Replicate 156, 29 iterations, total sum of distances = 518.578.
# Replicate 90, 15 iterations, total sum of distances = 520.606.
# Replicate 166, 10 iterations, total sum of distances = 520.825.
# Replicate 186, 42 iterations, total sum of distances = 516.465.
# Replicate 200, 11 iterations, total sum of distances = 518.298.
# Replicate 36, 13 iterations, total sum of distances = 519.157.
# Replicate 199, 37 iterations, total sum of distances = 515.941.
# Replicate 191, 23 iterations, total sum of distances = 519.651.
# Replicate 141, 40 iterations, total sum of distances = 518.862.
# Replicate 148, 15 iterations, total sum of distances = 516.981.
# Replicate 184, 21 iterations, total sum of distances = 515.717.
# Replicate 143, 37 iterations, total sum of distances = 517.493.
# Replicate 194, 17 iterations, total sum of distances = 517.922.
# Replicate 149, 28 iterations, total sum of distances = 516.965.
# Replicate 140, 10 iterations, total sum of distances = 519.898.
# Replicate 188, 35 iterations, total sum of distances = 516.485.
# Replicate 195, 11 iterations, total sum of distances = 522.125.
# Replicate 157, 20 iterations, total sum of distances = 518.279.
# Replicate 197, 30 iterations, total sum of distances = 516.072.
# Replicate 196, 17 iterations, total sum of distances = 524.481.
# Replicate 152, 29 iterations, total sum of distances = 517.289.
# Replicate 67, 21 iterations, total sum of distances = 518.104.
# Replicate 66, 21 iterations, total sum of distances = 520.683.
# Replicate 174, 11 iterations, total sum of distances = 517.664.
# Best total sum of distances = 515.33
# Saved DataFrame to CopBET_LSD_data_ses-LSD_PLCB_task-rest/metastate_series_complexity_CopBET_LSD_data_ses-LSD_PLCB_task-rest.csv
# metastate_series_complexity finished
# Working on entropy calculations for session: 1
# Working on entropy calculations for session: 2
# Working on entropy calculations for session: 3
# Working on entropy calculations for session: 4

# %% [markdown]
# At last, the entropies are calculated! As you can see, once the computer is assembled, computing all the entropies is very straightforward. The `savedata` parameter for each function is just to choose whether you want the results saved in a .csv in the provided directory `dir_name`. The default is `True`. Feel free to cross-check the entropy values produced by the Python code with those from the MATLAB functions (just note that the order of the files is different, so the order of the entropies is as well).
